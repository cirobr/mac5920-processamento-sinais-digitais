# %% [markdown]
# # Exemplos de carregamento de sinais de áudio e vídeo de urls e arquivos locais

# %%
import io
from urllib.request import urlopen
import scipy.io.wavfile as wavfile
import soundfile as sf
from imageio import imread
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
# para abrir arquivo wav de url:
url="https://github.com/carloselcastro/carloselcastro.github.io/raw/master/files/hellom.wav"
x, rate = sf.read(io.BytesIO(urlopen(url).read()))
plt.plot(x)
plt.show()
ipd.Audio(x.T, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# para abrir arquivo wav local (use um arquivo que esteja no mesmo local):
rate, x = wavfile.read('hellof.wav')
plt.plot(x)
plt.show()
ipd.Audio(x.T, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# para abrir imagem de url
url = "http://sutherncharm.files.wordpress.com/2009/09/double-ferris.jpg"
M = imread(urlopen(url).read())
plt.imshow(M)

# %%
# escolha um arquivo que esteja no mesmo local
M = imread("double-ferris.jpg")
plt.imshow(M)
